# %% [markdown]
# ** True or B always True
# ** False and B always False

# %%
if 10/0 or 2:
    print("we got no error")# ZeroDivisionError: division by zero
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 if 10/0 or 2:
#       2     print("we got no error")
#
# ZeroDivisionError: division by zero

# %%
if 2 or 10/0:
    print("we got no error")
# Out:
# we got no error
